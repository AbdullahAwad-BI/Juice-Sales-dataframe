# %%
import pandas as pd

# %%
jusice_dataframe=pd.read_excel(r"C:\Users\Rahhal\Desktop\DataSets\Excel Data\Juice_Sales_Dataset.xlsx")

# %%
jusice_dataframe
# Out:
#        Store_ID    Juice_Type           Month  Month_Number  Units_Sold  \
# 0     Store_001  Orange Juice    January 2024             1         121
# 1     Store_001  Orange Juice   February 2024             2         137
# 2     Store_001  Orange Juice      March 2024             3         137
# 3     Store_001  Orange Juice      April 2024             4         253
# 4     Store_001  Orange Juice        May 2024             5         219
# ...         ...           ...             ...           ...         ...
# 1915  Store_010  Papaya Juice     August 2024             8         193
# 1916  Store_010  Papaya Juice  September 2024             9         155
# 1917  Store_010  Papaya Juice    October 2024            10          96
# 1918  Store_010  Papaya Juice   November 2024            11         145
# 1919  Store_010  Papaya Juice   December 2024            12         229
#
#       Price_Per_Unit  Monthly_Sales  Revenue  Customer_Satisfaction  \
# ...

# %% [markdown]
# ## Displaed all dataFrame

# %%
pd.options.display.max_rows=1920

# %%
jusice_dataframe
# Out:
#        Store_ID           Juice_Type           Month  Month_Number  \
# 0     Store_001         Orange Juice    January 2024             1
# 1     Store_001         Orange Juice   February 2024             2
# 2     Store_001         Orange Juice      March 2024             3
# 3     Store_001         Orange Juice      April 2024             4
# 4     Store_001         Orange Juice        May 2024             5
# 5     Store_001         Orange Juice       June 2024             6
# 6     Store_001         Orange Juice       July 2024             7
# 7     Store_001         Orange Juice     August 2024             8
# 8     Store_001         Orange Juice  September 2024             9
# 9     Store_001         Orange Juice    October 2024            10
# 10    Store_001         Orange Juice   November 2024            11
# 11    Store_001         Orange Juice   December 2024            12
# 12    Store_001          Apple Juice    January 2024             1
# ...

# %% [markdown]
# ## Analyizing Market Performance : Revenue & Customer_Satisfaction for "Pineapple Juice" And "Apple Juice"

# %%
jusice1=jusice_dataframe[(jusice_dataframe["Juice_Type"]=="Apple Juice")&(jusice_dataframe["Monthly_Sales"]>1200)&(jusice_dataframe["Customer_Satisfaction"]>4.7)|(jusice_dataframe["Juice_Type"]=="Pineapple Juice")&(jusice_dataframe["Monthly_Sales"]>1200)&(jusice_dataframe["Customer_Satisfaction"]>4.7)]

# %%
jusice1
# Out:
#        Store_ID       Juice_Type           Month  Month_Number  Units_Sold  \
# 38    Store_001  Pineapple Juice      March 2024             3         217
# 229   Store_002  Pineapple Juice   February 2024             2         190
# 236   Store_002  Pineapple Juice  September 2024             9          88
# 239   Store_002  Pineapple Juice   December 2024            12         267
# 806   Store_005  Pineapple Juice      March 2024             3         137
# 808   Store_005  Pineapple Juice        May 2024             5          87
# 981   Store_006      Apple Juice    October 2024            10         136
# 997   Store_006  Pineapple Juice   February 2024             2          61
# 1360  Store_008      Apple Juice        May 2024             5         272
# 1361  Store_008      Apple Juice       June 2024             6         153
# 1367  Store_008      Apple Juice   December 2024            12         225
# ...

# %% [markdown]
# ## Descending order from most-selling to least-selling during the Month

# %%
decsending=jusice_dataframe.sort_values(by="Monthly_Sales",ascending=False)

# %%
decsending
# Out:
#        Store_ID           Juice_Type           Month  Month_Number  \
# 374   Store_002         Papaya Juice      March 2024             3
# 542   Store_003      Blueberry Juice      March 2024             3
# 685   Store_004    Pomegranate Juice   February 2024             2
# 1489  Store_008          Peach Juice   February 2024             2
# 782   Store_005          Apple Juice      March 2024             3
# 253   Store_002     Strawberry Juice   February 2024             2
# 1106  Store_006          Peach Juice      March 2024             3
# 1491  Store_008          Peach Juice      April 2024             4
# 687   Store_004    Pomegranate Juice      April 2024             4
# 554   Store_003      Cranberry Juice      March 2024             3
# 663   Store_004          Grape Juice      April 2024             4
# 757   Store_004         Papaya Juice   February 2024             2
# 1875  Store_010          Peach Juice      April 2024             4
# ...

# %% [markdown]
# ## Top 5 selling During Month

# %%
decsending.head(5)
# Out:
#        Store_ID         Juice_Type          Month  Month_Number  Units_Sold  \
# 374   Store_002       Papaya Juice     March 2024             3         208
# 542   Store_003    Blueberry Juice     March 2024             3         285
# 685   Store_004  Pomegranate Juice  February 2024             2          57
# 1489  Store_008        Peach Juice  February 2024             2         123
# 782   Store_005        Apple Juice     March 2024             3         193
#
#       Price_Per_Unit  Monthly_Sales  Revenue  Customer_Satisfaction  \
# 374             5.28           4662  1098.27                    5.0
# 542             5.52           4329  1572.77                    4.0
# 685             2.77           4314   158.11                    3.7
# 1489            6.36           4289   782.66                    3.4
# 782             3.81           4280   735.90                    3.9
#
#       Reorder_Rate
# 374           0.70
# 542           0.72
# 685           0.97
# ...

# %% [markdown]
# ## Most-selling during the Month

# %%
decsending.loc[[374]]
# Out:
#       Store_ID    Juice_Type       Month  Month_Number  Units_Sold  \
# 374  Store_002  Papaya Juice  March 2024             3         208
#
#      Price_Per_Unit  Monthly_Sales  Revenue  Customer_Satisfaction  \
# 374            5.28           4662  1098.27                    5.0
#
#      Reorder_Rate
# 374           0.7

# %% [markdown]
# ## Monthly sales that are greater than or equal 3000

# %%
juice2=jusice_dataframe[jusice_dataframe["Monthly_Sales"]>=3000]

# %%
juice2
# Out:
#        Store_ID           Juice_Type          Month  Month_Number  Units_Sold  \
# 24    Store_001          Mango Juice   January 2024             1          94
# 26    Store_001          Mango Juice     March 2024             3         280
# 74    Store_001          Lemon Juice     March 2024             3         134
# 120   Store_001          Guava Juice   January 2024             1          99
# 121   Store_001          Guava Juice  February 2024             2         106
# 122   Store_001          Guava Juice     March 2024             3         191
# 132   Store_001  Passion Fruit Juice   January 2024             1          95
# 134   Store_001  Passion Fruit Juice     March 2024             3          97
# 135   Store_001  Passion Fruit Juice     April 2024             4         229
# 136   Store_001  Passion Fruit Juice       May 2024             5         264
# 146   Store_001          Peach Juice     March 2024             3         201
# ...

# %% [markdown]
# ## Reorder Rate for juice sales that are grater than 0.6

# %%
juice3=jusice_dataframe[jusice_dataframe["Reorder_Rate"]>0.6]

# %%
juice3
# Out:
#        Store_ID           Juice_Type           Month  Month_Number  \
# 0     Store_001         Orange Juice    January 2024             1
# 1     Store_001         Orange Juice   February 2024             2
# 2     Store_001         Orange Juice      March 2024             3
# 3     Store_001         Orange Juice      April 2024             4
# 4     Store_001         Orange Juice        May 2024             5
# 5     Store_001         Orange Juice       June 2024             6
# 6     Store_001         Orange Juice       July 2024             7
# 7     Store_001         Orange Juice     August 2024             8
# 8     Store_001         Orange Juice  September 2024             9
# 9     Store_001         Orange Juice    October 2024            10
# 10    Store_001         Orange Juice   November 2024            11
# 11    Store_001         Orange Juice   December 2024            12
# 12    Store_001          Apple Juice    January 2024             1
# ...

# %% [markdown]
# ## Analyizing Market Performance :Reorder_Rate for "Orange Juice" And "Mango Juice" that are grater or equal 0.6

# %%
juice4=jusice_dataframe[(jusice_dataframe["Juice_Type"]=="Mango Juice")&(jusice_dataframe["Reorder_Rate"]>=0.6)|(jusice_dataframe["Juice_Type"]=="Orange Juice")&(jusice_dataframe["Reorder_Rate"]>=0.6)]

# %%
juice4
# Out:
#        Store_ID    Juice_Type           Month  Month_Number  Units_Sold  \
# 0     Store_001  Orange Juice    January 2024             1         121
# 1     Store_001  Orange Juice   February 2024             2         137
# 2     Store_001  Orange Juice      March 2024             3         137
# 3     Store_001  Orange Juice      April 2024             4         253
# 4     Store_001  Orange Juice        May 2024             5         219
# 5     Store_001  Orange Juice       June 2024             6         239
# 6     Store_001  Orange Juice       July 2024             7         100
# 7     Store_001  Orange Juice     August 2024             8          63
# 8     Store_001  Orange Juice  September 2024             9         160
# 9     Store_001  Orange Juice    October 2024            10         130
# 10    Store_001  Orange Juice   November 2024            11         155
# 11    Store_001  Orange Juice   December 2024            12         251
# ...

# %%
## Analyizing Market Performance :Reorder_Rate for "Orange Juice" And "Mango Juice" that are Equal 0.6

# %%
juice5=jusice_dataframe[(jusice_dataframe["Juice_Type"]=="Mango Juice")&(jusice_dataframe["Reorder_Rate"]==0.6)|(jusice_dataframe["Juice_Type"]=="Orange Juice")&(jusice_dataframe["Reorder_Rate"]==0.6)]

# %%
juice5
# Out:
#       Store_ID    Juice_Type       Month  Month_Number  Units_Sold  \
# 578  Store_004  Orange Juice  March 2024             3         195
#
#      Price_Per_Unit  Monthly_Sales  Revenue  Customer_Satisfaction  \
# 578            5.04           1651   982.35                    4.5
#
#      Reorder_Rate
# 578           0.6
